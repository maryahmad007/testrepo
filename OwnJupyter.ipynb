# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
#  **Maryam Ahmad** <br> I am half human and half unicorn

# %% [markdown]
# *I am interested in data science because I find it quite interesting*

# %% [markdown]
# ### The following code tests the Gauss Formula

# %%
def gauss(n):
    return (n*(n+1))/2
gauss(100) == sum(range(101))
# Out:
# True

# %% [markdown]
# - This is a bullet
# - This is the second bullet

# %% [markdown]
# 1. Line number one
# 2. Line number two

# %% [markdown]
# Here is an Image I've chosen:
# ![images.jpg](attachment:images.jpg)

# %% [markdown]
# <font color=red>I've made the font colour RED</font>

# %% [markdown]
# Please use this link to go to the Google Search Engine:
# [Click here to Google](https://www.google.com/)
